# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
import time

# browser driver setting
s = Service("./chromedriver.exe")
driver = webdriver.Chrome(service=s)

def get_page_info(city_name, page_range):
    page_info_list = []
    for page in range(1, page_range + 1):
        driver.get('https://www.sinyi.com.tw/buy/list' + '/' + city_name + '/' + str(page)) 
        time.sleep(5)
        
        info = driver.page_source
        time.sleep(5)
        page_info_list.append(info)
        
    driver.close()   
    return page_info_list

def get_houseID(info):
    
    soup = BeautifulSoup(info, 'html.parser')
    div_tags = soup.find_all('div', {'class':'buy-list-item'})

    count = 0
    houseID_list = []
    for i in div_tags:
        href_info = str(i)
        house_id = href_info.split('/buy/house/')[-1].split('/?breadcrumb=list')[0]
        houseID_list.append(house_id)
        # urls =  'https://www.sinyi.com.tw/buy/house/' + house_id
        # url_list.append(urls)
    return houseID_list

def save_image(houseID_list, img_no):
    
    for i in houseID_list:
        src = 'https://res.sinyi.com.tw/buy/' + i + '/bigimg/E.JPG'
        img_no += 1
        urlretrieve(src, './images/' + str(img_no) + '.jpg')
        print('save image: {} .jpg'.format(img_no))
        time.sleep(2)
    print("finish to image:{}".format(img_no))
    return(img_no)
        

# set city
city_name = 'Taipei-city'
# set page range
page_range = 5
# set image number from 1 start
img_no = 0

page_info_list = get_page_info(city_name, page_range)

for i in page_info_list:
    houseID_list = get_houseID(i)
    img_no = save_image(houseID_list, img_no)

print('done')
# Out:
# save image: 1 .jpg
# save image: 2 .jpg
# save image: 3 .jpg
# save image: 4 .jpg
# save image: 5 .jpg
# save image: 6 .jpg
# save image: 7 .jpg
# save image: 8 .jpg
# save image: 9 .jpg
# save image: 10 .jpg
# save image: 11 .jpg
# save image: 12 .jpg
# save image: 13 .jpg
# save image: 14 .jpg
# save image: 15 .jpg
# save image: 16 .jpg
# save image: 17 .jpg
# save image: 18 .jpg
# save image: 19 .jpg
# save image: 20 .jpg
# finish to image:20
# save image: 21 .jpg
# save image: 22 .jpg
# save image: 23 .jpg
# save image: 24 .jpg
# save image: 25 .jpg
# save image: 26 .jpg
# save image: 27 .jpg
# save image: 28 .jpg
# save image: 29 .jpg
# save image: 30 .jpg
# save image: 31 .jpg
# save image: 32 .jpg
# save image: 33 .jpg
# save image: 34 .jpg
# save image: 35 .jpg
# save image: 36 .jpg
# save image: 37 .jpg
# save image: 38 .jpg
# save image: 39 .jpg
# save image: 40 .jpg
# finish to image:40
# save image: 41 .jpg
# save image: 42 .jpg
# save image: 43 .jpg
# save image: 44 .jpg
# save image: 45 .jpg
# save image: 46 .jpg
# save image: 47 .jpg
# save image: 48 .jpg
# save image: 49 .jpg
# save image: 50 .jpg
# save image: 51 .jpg
# save image: 52 .jpg
# save image: 53 .jpg
# save image: 54 .jpg
# save image: 55 .jpg
# save image: 56 .jpg
# save image: 57 .jpg
# save image: 58 .jpg
# save image: 59 .jpg
# save image: 60 .jpg
# finish to image:60
# save image: 61 .jpg
# save image: 62 .jpg
# save image: 63 .jpg
# save image: 64 .jpg
# save image: 65 .jpg
# save image: 66 .jpg
# save image: 67 .jpg
# save image: 68 .jpg
# save image: 69 .jpg
# save image: 70 .jpg
# save image: 71 .jpg
# save image: 72 .jpg
# save image: 73 .jpg
# save image: 74 .jpg
# save image: 75 .jpg
# save image: 76 .jpg
# save image: 77 .jpg
# save image: 78 .jpg
# save image: 79 .jpg
# save image: 80 .jpg
# finish to image:80
# save image: 81 .jpg
# save image: 82 .jpg
# save image: 83 .jpg
# save image: 84 .jpg
# save image: 85 .jpg
# save image: 86 .jpg
# save image: 87 .jpg
# save image: 88 .jpg
# save image: 89 .jpg
# save image: 90 .jpg
# save image: 91 .jpg
# save image: 92 .jpg
# save image: 93 .jpg
# save image: 94 .jpg
# save image: 95 .jpg
# save image: 96 .jpg
# save image: 97 .jpg
# save image: 98 .jpg
# save image: 99 .jpg
# save image: 100 .jpg
# finish to image:100
